# %% [markdown]
# # Data Cleaning - Shark Tank India

# %%
import pandas as pd

# %% [markdown]
# * Loading CSV file

# %%
df = pd.read_csv("ShartankIndiaAllPitches.csv")

# %%
df.head(5)
# Out:
#    Episode Number  Pitch Number                Brand  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             Idea  \
# 0                                   Frozen Momos
# 1  Renting e-bike for mobility in private spaces
# 2                             Detachable Sleeves
# 3                           Healthy Potato Chips
# 4                       Brain Development Course
#
#    Investment Amount (In Lakhs INR)   Debt (In lakhs INR) Equity Anupam  \
# 0                                 75                    0    18%      N
# 1                                 40                    0    50%      N
# 2                                 25                    0    30%      Y
# 3                                 70                    0  2.75%      N
# 4                                  0                    0      0      N
#
#   Ashneer Namita Aman Peyush Vineeta Ghazal  Season
# 0       Y      N    Y      N       Y      N       1
# 1       Y      N    N      N       Y      N       1
# 2       N      N    N      N       Y      N       1
# 3       Y      N    N      N       N      N       1
# 4       N      N    N      N       N      N       1

# %% [markdown]
# * Renaming columns

# %%
df.columns
# Out:
# Index(['Episode Number', 'Pitch Number', 'Brand', 'Idea',
#        'Investment Amount (In Lakhs INR) ', 'Debt (In lakhs INR)', 'Equity',
#        'Anupam', 'Ashneer', 'Namita', 'Aman', 'Peyush', 'Vineeta', 'Ghazal',
#        'Season'],
#       dtype='object')

# %%
df.rename(columns={
    'Episode Number': 'episode',
    'Pitch Number': 'pitch_number',
    'Brand': 'startup_name',
    'Idea': 'business_idea',
    'Investment Amount (In Lakhs INR) ': 'investment_amount_lakhs',
    'Debt (In lakhs INR)': 'debt_amount_lakhs',
    'Equity': 'equity',
    'Anupam': 'anupam',
    'Ashneer': 'ashneer',
    'Namita': 'namita',
    'Aman': 'aman',
    'Peyush': 'peyush',
    'Vineeta': 'vineeta',
    'Ghazal': 'ghazal',
    'Season': 'season'
}, inplace=True)

# %%
df.columns
# Out:
# Index(['episode', 'pitch_number', 'startup_name', 'business_idea',
#        'investment_amount_lakhs', 'debt_amount_lakhs', 'equity', 'anupam',
#        'ashneer', 'namita', 'aman', 'peyush', 'vineeta', 'ghazal', 'season'],
#       dtype='object')

# %% [markdown]
# * Cleaning Numeric Columns

# %%
df['investment_amount_lakhs'] = pd.to_numeric(df['investment_amount_lakhs'], errors='coerce').fillna(0)
df['debt_amount_lakhs'] = pd.to_numeric(df['debt_amount_lakhs'], errors='coerce').fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   episode                  117 non-null    int64
#  1   pitch_number             117 non-null    int64
#  2   startup_name             117 non-null    object
#  3   business_idea            117 non-null    object
#  4   investment_amount_lakhs  117 non-null    int64
#  5   debt_amount_lakhs        117 non-null    int64
#  6   equity                   117 non-null    object
#  7   anupam                   117 non-null    object
#  8   ashneer                  117 non-null    object
#  9   namita                   117 non-null    object
#  10  aman                     117 non-null    object
#  11  peyush                   117 non-null    object
#  12  vineeta                  117 non-null    object
#  13  ghazal                   117 non-null    object
#  14  season                   117 non-null    int64
# dtypes: int64(5), object(10)
# memory usage: 13.8+ KB

# %% [markdown]
# * Clean Equity

# %%
df['equity'] = df['equity'].str.replace('%', '', regex=False)
df['equity'] = pd.to_numeric(df['equity'], errors='coerce').fillna(0)

# %%
df.head(5)
# Out:
#    episode  pitch_number         startup_name  \
# 0        1             1  BluePine Industries
# 1        1             2        Booz scooters
# 2        1             3  Heart up my Sleeves
# 3        2             4           Tagz Foods
# 4        2             5       Head and Heart
#
#                                    business_idea  investment_amount_lakhs  \
# 0                                   Frozen Momos                       75
# 1  Renting e-bike for mobility in private spaces                       40
# 2                             Detachable Sleeves                       25
# 3                           Healthy Potato Chips                       70
# 4                       Brain Development Course                        0
#
#    debt_amount_lakhs  equity anupam ashneer namita aman peyush vineeta ghazal  \
# 0                  0   18.00      N       Y      N    Y      N       Y      N
# 1                  0   50.00      N       Y      N    N      N       Y      N
# 2                  0   30.00      Y       N      N    N      N       Y      N
# 3                  0    2.75      N       Y      N    N      N       N      N
# 4                  0    0.00      N       N      N    N      N       N      N
#
#    season
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   episode                  117 non-null    int64
#  1   pitch_number             117 non-null    int64
#  2   startup_name             117 non-null    object
#  3   business_idea            117 non-null    object
#  4   investment_amount_lakhs  117 non-null    int64
#  5   debt_amount_lakhs        117 non-null    int64
#  6   equity                   117 non-null    float64
#  7   anupam                   117 non-null    object
#  8   ashneer                  117 non-null    object
#  9   namita                   117 non-null    object
#  10  aman                     117 non-null    object
#  11  peyush                   117 non-null    object
#  12  vineeta                  117 non-null    object
#  13  ghazal                   117 non-null    object
#  14  season                   117 non-null    int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 13.8+ KB

# %% [markdown]
# * Converting Shark Votes to Binary

# %%
shark_columns = ['anupam', 'ashneer', 'namita', 'aman', 'peyush', 'vineeta', 'ghazal']
for shark in shark_columns:
    df[shark] = df[shark].str.upper().map({'Y': 1, 'N': 0}).fillna(0).astype(int)

# %%
df.head(5)
# Out:
#    episode  pitch_number         startup_name  \
# 0        1             1  BluePine Industries
# 1        1             2        Booz scooters
# 2        1             3  Heart up my Sleeves
# 3        2             4           Tagz Foods
# 4        2             5       Head and Heart
#
#                                    business_idea  investment_amount_lakhs  \
# 0                                   Frozen Momos                       75
# 1  Renting e-bike for mobility in private spaces                       40
# 2                             Detachable Sleeves                       25
# 3                           Healthy Potato Chips                       70
# 4                       Brain Development Course                        0
#
#    debt_amount_lakhs  equity  anupam  ashneer  namita  aman  peyush  vineeta  \
# 0                  0   18.00       0        1       0     1       0        1
# 1                  0   50.00       0        1       0     0       0        1
# 2                  0   30.00       1        0       0     0       0        1
# 3                  0    2.75       0        1       0     0       0        0
# 4                  0    0.00       0        0       0     0       0        0
#
#    ghazal  season
# 0       0       1
# 1       0       1
# 2       0       1
# 3       0       1
# 4       0       1

# %% [markdown]
# * Saving Cleaned Data

# %%
df.to_csv("Cleaned_SharkTankIndia.csv", index=False)
